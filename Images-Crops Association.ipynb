# %%
! pip install natsort
# Out:
# Requirement already satisfied: natsort in c:\users\anshu\anaconda3\lib\site-packages (6.0.0)

# %%
import cv2
import numpy as np
import glob
import re
import os
from natsort import natsorted,ns
import json

# %%
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
mylistcrop = os.listdir("Cropped Images")
mylistcrop = natsorted(mylistcrop, alg=ns.IGNORECASE)
mylistimage = os.listdir("Real Images")
mylistimage = natsorted(mylistimage, alg=ns.IGNORECASE)

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %%
count = 0
imagedict = {}
list2 = []
list3 = []
list4 = []
for j in sorted(glob.iglob("Real Images\*"), key= numericalSort):
    value = -1
    print(mylistimage[count])
    imagedict[mylistimage[count]] = []
    list3.clear()
    list4.clear()
    for f in sorted(glob.iglob("Cropped Images\*"), key= numericalSort):
        img = cv2.imread(j)
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)        
        template = cv2.imread(f, cv2.IMREAD_GRAYSCALE)
        w, h = 0, 0
        w, h = template.shape[::-1]
        img_shape = list(gray_img.shape)
        crop_shape = list(template.shape)
        value = value+1
        list2.clear()
        list1 = [item1 for item1, item2 in zip(img_shape, crop_shape) if item1 > item2]
        if ((len(list1))==2):
            pass
        else:
            continue
        result = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
        loc = np.where(result >= 0.9)
        pt = 0
        for pt in zip(*loc[::-1]):
            list2 = [pt[0], pt[1], (pt[0] + w), (pt[1] + h)]
        if not list2:
            continue
        tup1 = (mylistcrop[value], [pt[0], pt[1], (pt[0] + w), (pt[1] + h)])
        imagedict[mylistimage[count]].append(tup1)
    print(imagedict[mylistimage[count]])
    count = count +1
# Out:
# image_name_0.jpg
# [('crop_name_150.jpg', [115, 133, 268, 437]), ('crop_name_153.jpg', [147, 532, 229, 581])]
# image_name_1.jpg
# [('crop_name_110.jpg', [262, 892, 1407, 1786]), ('crop_name_238.jpg', [762, 1599, 778, 1633])]
# image_name_2.jpg
# [('crop_name_268.jpg', [127, 34, 156, 79])]
# image_name_3.jpg
# [('crop_name_238.jpg', [963, 479, 979, 513])]
# image_name_4.jpg
# [('crop_name_55.jpg', [167, 300, 267, 453]), ('crop_name_76.jpg', [167, 300, 267, 453])]
# image_name_5.jpg
# []
# image_name_6.jpg
# [('crop_name_238.jpg', [242, 308, 258, 342])]
# image_name_7.jpg
# []
# image_name_8.jpg
# [('crop_name_238.jpg', [67, 415, 83, 449])]
# image_name_9.jpg
# [('crop_name_36.jpg', [97, 242, 264, 508])]
# image_name_10.jpg
# []
# image_name_11.jpg
# [('crop_name_130.jpg', [504, 762, 561, 797]), ('crop_name_221.jpg', [179, 328, 510, 781])]
# image_name_12.jpg
# []
# image_name_13.jpg
# []
# image_name_14.jpg
# [('crop_name_184.jpg', [485, 1075, 634, 1280]), ('crop_name_200.jpg', [485, 1075, 634, 1280])]
# image_name_15.jpg
# [('crop_name_148.jpg', [13, 43, 1011, 835])]
# image_name_16.jpg
# [('crop_name_120.jpg', [49, 481, 415, 735]), ('crop_name_238.jpg', [346, 493, 362, 527])]
# image_name_17.jpg
# []
# image_name_18.jpg
# [('crop_name_238.jpg', [260, 98, 276, 132])]
# image_name_19.jpg
# []
# image_name_20.jpg
# [('crop_name_238.jpg', [261, 287, 277, 321])]
# image_name_21.jpg
# []
# image_name_22.jpg
# [('crop_name_238.jpg', [279, 497, 295, 531])]
# image_name_23.jpg
# [('crop_name_167.jpg', [118, 322, 280, 530])]
# image_name_24.jpg
# []
# image_name_25.jpg
# []
# image_name_26.jpg
# []
# image_name_27.jpg
# [('crop_name_238.jpg', [197, 635, 213, 669])]
# image_name_28.jpg
# []
# image_name_29.jpg
# [('crop_name_97.jpg', [243, 644, 702, 1091]), ('crop_name_215.jpg', [243, 644, 702, 1091])]
# image_name_30.jpg
# [('crop_name_238.jpg', [203, 382, 219, 416])]
# image_name_31.jpg
# [('crop_name_238.jpg', [145, 228, 161, 262])]
# image_name_32.jpg
# [('crop_name_238.jpg', [199, 473, 215, 507])]
# image_name_33.jpg
# []
# image_name_34.jpg
# [('crop_name_268.jpg', [164, 441, 193, 486])]
# image_name_35.jpg
# [('crop_name_82.jpg', [9, 11, 147, 292]), ('crop_name_268.jpg', [113, 309, 142, 354])]
# image_name_36.jpg
# [('crop_name_268.jpg', [100, 308, 129, 353])]
# image_name_37.jpg
# []
# image_name_38.jpg
# [('crop_name_12.jpg', [155, 510, 186, 566])]
# image_name_39.jpg
# [('crop_name_238.jpg', [392, 442, 408, 476])]
# image_name_40.jpg
# []
# image_name_41.jpg
# []
# image_name_42.jpg
# [('crop_name_264.jpg', [195, 1100, 239, 1178]), ('crop_name_268.jpg', [139, 195, 168, 240])]
# image_name_43.jpg
# [('crop_name_238.jpg', [208, 108, 224, 142]), ('crop_name_268.jpg', [197, 206, 226, 251])]
# image_name_44.jpg
# [('crop_name_193.jpg', [587, 790, 659, 834])]
# image_name_45.jpg
# []
# image_name_46.jpg
# [('crop_name_2.jpg', [185, 317, 272, 531]), ('crop_name_78.jpg', [148, 19, 258, 95])]
# image_name_47.jpg
# [('crop_name_238.jpg', [43, 524, 59, 558])]
# image_name_48.jpg
# [('crop_name_238.jpg', [234, 405, 250, 439])]
# image_name_49.jpg
# [('crop_name_256.jpg', [123, 452, 174, 534])]
# image_name_50.jpg
# []
# image_name_51.jpg
# []
# image_name_52.jpg
# [('crop_name_84.jpg', [246, 200, 757, 785])]
# image_name_53.jpg
# []
# image_name_54.jpg
# [('crop_name_268.jpg', [488, 1005, 517, 1050])]
# image_name_55.jpg
# [('crop_name_173.jpg', [290, 244, 463, 304])]
# image_name_56.jpg
# [('crop_name_260.jpg', [143, 187, 276, 408])]
# image_name_57.jpg
# []
# image_name_58.jpg
# []
# image_name_59.jpg
# []
# image_name_60.jpg
# [('crop_name_240.jpg', [367, 68, 762, 763])]
# image_name_61.jpg
# []
# image_name_62.jpg
# [('crop_name_113.jpg', [37, 214, 500, 576])]
# image_name_63.jpg
# [('crop_name_201.jpg', [24, 32, 319, 359])]
# image_name_64.jpg
# []
# image_name_65.jpg
# []
# image_name_66.jpg
# [('crop_name_238.jpg', [682, 829, 698, 863])]
# image_name_67.jpg
# [('crop_name_80.jpg', [569, 158, 983, 1020]), ('crop_name_238.jpg', [866, 795, 882, 829])]
# image_name_68.jpg
# []
# image_name_69.jpg
# [('crop_name_263.jpg', [174, 65, 552, 902])]
# image_name_70.jpg
# []
# image_name_71.jpg
# [('crop_name_238.jpg', [156, 36, 172, 70])]
# image_name_72.jpg
# []
# image_name_73.jpg
# [('crop_name_238.jpg', [745, 753, 761, 787])]
# image_name_74.jpg
# [('crop_name_109.jpg', [296, 297, 336, 350])]
# image_name_75.jpg
# [('crop_name_242.jpg', [53, 71, 205, 364])]
# image_name_76.jpg
# [('crop_name_159.jpg', [270, 333, 369, 479])]
# image_name_77.jpg
# [('crop_name_238.jpg', [842, 628, 858, 662]), ('crop_name_268.jpg', [30, 587, 59, 632])]
# image_name_78.jpg
# [('crop_name_71.jpg', [130, 100, 306, 388]), ('crop_name_268.jpg', [179, 408, 208, 453])]
# image_name_79.jpg
# [('crop_name_238.jpg', [268, 265, 284, 299])]
# image_name_80.jpg
# []
# image_name_81.jpg
# [('crop_name_238.jpg', [201, 267, 217, 301])]
# image_name_82.jpg
# [('crop_name_140.jpg', [11, 209, 492, 571])]
# image_name_83.jpg
# [('crop_name_37.jpg', [150, 643, 205, 724]), ('crop_name_111.jpg', [150, 643, 205, 724]), ('crop_name_238.jpg', [295, 528, 311, 562])]
# image_name_84.jpg
# []
# image_name_85.jpg
# []
# image_name_86.jpg
# []
# image_name_87.jpg
# []
# image_name_88.jpg
# [('crop_name_238.jpg', [462, 635, 478, 669]), ('crop_name_268.jpg', [144, 867, 173, 912])]
# image_name_89.jpg
# []
# image_name_90.jpg
# [('crop_name_135.jpg', [194, 513, 241, 600]), ('crop_name_138.jpg', [112, 336, 191, 463])]
# image_name_91.jpg
# []
# image_name_92.jpg
# [('crop_name_35.jpg', [300, 275, 362, 380]), ('crop_name_251.jpg', [108, 147, 285, 393])]
# image_name_93.jpg
# []
# image_name_94.jpg
# []
# image_name_95.jpg
# [('crop_name_44.jpg', [117, 268, 511, 1004]), ('crop_name_238.jpg', [159, 599, 175, 633])]
# image_name_96.jpg
# []
# image_name_97.jpg
# []
# image_name_98.jpg
# [('crop_name_160.jpg', [144, 266, 245, 558]), ('crop_name_238.jpg', [180, 431, 196, 465]), ('crop_name_273.jpg', [152, 270, 205, 304])]
# image_name_99.jpg
# [('crop_name_268.jpg', [203, 647, 232, 692])]
# image_name_100.jpg
# []
# image_name_101.jpg
# []
# image_name_102.jpg
# [('crop_name_238.jpg', [186, 443, 202, 477])]
# image_name_103.jpg
# []
# image_name_104.jpg
# [('crop_name_238.jpg', [572, 779, 588, 813]), ('crop_name_268.jpg', [196, 500, 225, 545])]
# image_name_105.jpg
# []
# image_name_106.jpg
# []
# image_name_107.jpg
# []
# image_name_108.jpg
# [('crop_name_238.jpg', [190, 232, 206, 266])]
# image_name_109.jpg
# [('crop_name_238.jpg', [402, 441, 418, 475])]
# image_name_110.jpg
# [('crop_name_115.jpg', [130, 106, 275, 356]), ('crop_name_125.jpg', [232, 524, 310, 586])]
# image_name_111.jpg
# [('crop_name_66.jpg', [172, 511, 201, 577]), ('crop_name_216.jpg', [172, 511, 201, 577])]
# image_name_112.jpg
# [('crop_name_39.jpg', [119, 112, 270, 325])]
# image_name_113.jpg
# []
# image_name_114.jpg
# []
# image_name_115.jpg
# []
# image_name_116.jpg
# []
# image_name_117.jpg
# [('crop_name_9.jpg', [12, 19, 471, 508]), ('crop_name_238.jpg', [420, 361, 436, 395]), ('crop_name_268.jpg', [27, 380, 56, 425])]
# image_name_118.jpg
# [('crop_name_238.jpg', [53, 845, 69, 879])]
# image_name_119.jpg
# []
# image_name_120.jpg
# [('crop_name_238.jpg', [156, 500, 172, 534]), ('crop_name_268.jpg', [136, 165, 165, 210])]
# image_name_121.jpg
# []
# image_name_122.jpg
# []
# image_name_123.jpg
# [('crop_name_238.jpg', [240, 450, 256, 484])]
# image_name_124.jpg
# [('crop_name_170.jpg', [49, 18, 904, 1216]), ('crop_name_238.jpg', [725, 819, 741, 853])]
# image_name_125.jpg
# [('crop_name_172.jpg', [173, 109, 365, 706])]
# image_name_126.jpg
# []
# image_name_127.jpg
# [('crop_name_230.jpg', [11, 256, 717, 1026])]
# image_name_128.jpg
# [('crop_name_194.jpg', [27, 402, 121, 477])]
# image_name_129.jpg
# []
# image_name_130.jpg
# []
# image_name_131.jpg
# [('crop_name_238.jpg', [210, 849, 226, 883])]
# image_name_132.jpg
# []
# image_name_133.jpg
# [('crop_name_71.jpg', [130, 1300, 306, 1588]), ('crop_name_194.jpg', [27, 1002, 121, 1077]), ('crop_name_268.jpg', [179, 1608, 208, 1653])]
# image_name_134.jpg
# [('crop_name_255.jpg', [141, 255, 255, 590])]
# image_name_135.jpg
# [('crop_name_238.jpg', [191, 522, 207, 556])]
# image_name_136.jpg
# []
# image_name_137.jpg
# []
# image_name_138.jpg
# []
# image_name_139.jpg
# [('crop_name_168.jpg', [172, 1517, 318, 1907]), ('crop_name_238.jpg', [281, 1713, 297, 1747])]
# image_name_140.jpg
# [('crop_name_238.jpg', [691, 467, 707, 501])]
# image_name_141.jpg
# []
# image_name_142.jpg
# [('crop_name_22.jpg', [191, 517, 239, 578])]
# image_name_143.jpg
# [('crop_name_131.jpg', [151, 88, 197, 126])]
# image_name_144.jpg
# [('crop_name_230.jpg', [11, 256, 717, 1026])]
# image_name_145.jpg
# [('crop_name_238.jpg', [178, 964, 194, 998])]
# image_name_146.jpg
# []
# image_name_147.jpg
# []
# image_name_148.jpg
# [('crop_name_26.jpg', [167, 462, 200, 513]), ('crop_name_46.jpg', [56, 229, 128, 303])]
# image_name_149.jpg
# [('crop_name_238.jpg', [480, 605, 496, 639]), ('crop_name_268.jpg', [129, 375, 158, 420])]
# image_name_150.jpg
# []
# image_name_151.jpg
# [('crop_name_238.jpg', [941, 1262, 957, 1296]), ('crop_name_268.jpg', [145, 340, 174, 385])]
# image_name_152.jpg
# []
# image_name_153.jpg
# []
# image_name_154.jpg
# [('crop_name_99.jpg', [109, 125, 268, 284]), ('crop_name_258.jpg', [109, 125, 268, 284])]
# image_name_155.jpg
# [('crop_name_238.jpg', [222, 249, 238, 283])]
# image_name_156.jpg
# [('crop_name_41.jpg', [197, 501, 233, 593]), ('crop_name_64.jpg', [96, 289, 290, 501])]
# image_name_157.jpg
# [('crop_name_238.jpg', [193, 333, 209, 367])]
# image_name_158.jpg
# []
# image_name_159.jpg
# [('crop_name_166.jpg', [199, 233, 304, 312]), ('crop_name_264.jpg', [218, 512, 262, 590])]
# image_name_160.jpg
# []
# image_name_161.jpg
# [('crop_name_238.jpg', [549, 66, 565, 100])]
# image_name_162.jpg
# [('crop_name_238.jpg', [359, 536, 375, 570])]
# image_name_163.jpg
# [('crop_name_238.jpg', [143, 374, 159, 408])]
# image_name_164.jpg
# []
# image_name_165.jpg
# [('crop_name_229.jpg', [120, 220, 1177, 819])]
# image_name_166.jpg
# [('crop_name_238.jpg', [354, 814, 370, 848])]
# image_name_167.jpg
# []
# image_name_168.jpg
# [('crop_name_228.jpg', [66, 274, 532, 495])]
# image_name_169.jpg
# []
# image_name_170.jpg
# []
# image_name_171.jpg
# []
# image_name_172.jpg
# []
# image_name_173.jpg
# []
# image_name_174.jpg
# [('crop_name_58.jpg', [160, 479, 187, 544]), ('crop_name_210.jpg', [194, 479, 217, 546])]
# image_name_175.jpg
# [('crop_name_238.jpg', [213, 102, 229, 136])]
# image_name_176.jpg
# []
# image_name_177.jpg
# [('crop_name_83.jpg', [181, 70, 234, 100])]
# image_name_178.jpg
# []
# image_name_179.jpg
# []
# image_name_180.jpg
# []
# image_name_181.jpg
# [('crop_name_238.jpg', [38, 619, 54, 653]), ('crop_name_250.jpg', [33, 660, 156, 724])]
# image_name_182.jpg
# [('crop_name_193.jpg', [206, 17, 278, 61])]
# image_name_183.jpg
# []
# image_name_184.jpg
# []
# image_name_185.jpg
# []
# image_name_186.jpg
# [('crop_name_102.jpg', [157, 525, 180, 577]), ('crop_name_238.jpg', [158, 76, 174, 110])]
# image_name_187.jpg
# [('crop_name_0.jpg', [10, 106, 945, 1264]), ('crop_name_1.jpg', [10, 106, 945, 1264]), ('crop_name_3.jpg', [10, 106, 945, 1264]), ('crop_name_4.jpg', [10, 106, 945, 1264]), ('crop_name_6.jpg', [10, 106, 945, 1264]), ('crop_name_8.jpg', [10, 106, 945, 1264]), ('crop_name_10.jpg', [10, 106, 945, 1264]), ('crop_name_11.jpg', [10, 106, 945, 1264]), ('crop_name_13.jpg', [10, 106, 945, 1264]), ('crop_name_15.jpg', [10, 106, 945, 1264]), ('crop_name_16.jpg', [10, 106, 945, 1264]), ('crop_name_17.jpg', [10, 106, 945, 1264]), ('crop_name_18.jpg', [10, 106, 945, 1264]), ('crop_name_19.jpg', [10, 106, 945, 1264]), ('crop_name_20.jpg', [10, 106, 945, 1264]), ('crop_name_21.jpg', [10, 106, 945, 1264]), ('crop_name_25.jpg', [10, 106, 945, 1264]), ('crop_name_27.jpg', [10, 106, 945, 1264]), ('crop_name_30.jpg', [10, 106, 945, 1264]), ('crop_name_31.jpg', [10, 106, 945, 1264]), ('crop_name_32.jpg', [10, 106, 945, 1264]), ('crop_name_33.jpg', [10, 106, 945, 1264]), ('crop_name_34.jpg', [10, 106, 945, 1264]), ('crop_name_38.jpg', [10, 106, 945, 1264]), ('crop_name_40.jpg', [10, 106, 945, 1264]), ('crop_name_42.jpg', [10, 106, 945, 1264]), ('crop_name_43.jpg', [10, 106, 945, 1264]), ('crop_name_47.jpg', [10, 106, 945, 1264]), ('crop_name_48.jpg', [10, 106, 945, 1264]), ('crop_name_49.jpg', [10, 106, 945, 1264]), ('crop_name_50.jpg', [10, 106, 945, 1264]), ('crop_name_51.jpg', [10, 106, 945, 1264]), ('crop_name_52.jpg', [10, 106, 945, 1264]), ('crop_name_57.jpg', [10, 106, 945, 1264]), ('crop_name_59.jpg', [10, 106, 945, 1264]), ('crop_name_60.jpg', [10, 106, 945, 1264]), ('crop_name_61.jpg', [10, 106, 945, 1264]), ('crop_name_62.jpg', [10, 106, 945, 1264]), ('crop_name_67.jpg', [10, 106, 945, 1264]), ('crop_name_69.jpg', [10, 106, 945, 1264]), ('crop_name_70.jpg', [10, 106, 945, 1264]), ('crop_name_72.jpg', [10, 106, 945, 1264]), ('crop_name_73.jpg', [10, 106, 945, 1264]), ('crop_name_75.jpg', [10, 106, 945, 1264]), ('crop_name_86.jpg', [10, 106, 945, 1264]), ('crop_name_87.jpg', [10, 106, 945, 1264]), ('crop_name_88.jpg', [10, 106, 945, 1264]), ('crop_name_89.jpg', [10, 106, 945, 1264]), ('crop_name_90.jpg', [10, 106, 945, 1264]), ('crop_name_94.jpg', [10, 106, 945, 1264]), ('crop_name_98.jpg', [10, 106, 945, 1264]), ('crop_name_101.jpg', [10, 106, 945, 1264]), ('crop_name_103.jpg', [10, 106, 945, 1264]), ('crop_name_107.jpg', [10, 106, 945, 1264]), ('crop_name_112.jpg', [10, 106, 945, 1264]), ('crop_name_114.jpg', [10, 106, 945, 1264]), ('crop_name_117.jpg', [10, 106, 945, 1264]), ('crop_name_122.jpg', [10, 106, 945, 1264]), ('crop_name_127.jpg', [10, 106, 945, 1264]), ('crop_name_129.jpg', [10, 106, 945, 1264]), ('crop_name_137.jpg', [10, 106, 945, 1264]), ('crop_name_141.jpg', [10, 106, 945, 1264]), ('crop_name_142.jpg', [10, 106, 945, 1264]), ('crop_name_143.jpg', [10, 106, 945, 1264]), ('crop_name_144.jpg', [10, 106, 945, 1264]), ('crop_name_145.jpg', [10, 106, 945, 1264]), ('crop_name_149.jpg', [10, 106, 945, 1264]), ('crop_name_152.jpg', [10, 106, 945, 1264]), ('crop_name_158.jpg', [10, 106, 945, 1264]), ('crop_name_161.jpg', [10, 106, 945, 1264]), ('crop_name_162.jpg', [10, 106, 945, 1264]), ('crop_name_164.jpg', [10, 106, 945, 1264]), ('crop_name_165.jpg', [10, 106, 945, 1264]), ('crop_name_176.jpg', [10, 106, 945, 1264]), ('crop_name_177.jpg', [10, 106, 945, 1264]), ('crop_name_180.jpg', [10, 106, 945, 1264]), ('crop_name_183.jpg', [10, 106, 945, 1264]), ('crop_name_186.jpg', [10, 106, 945, 1264]), ('crop_name_188.jpg', [10, 106, 945, 1264]), ('crop_name_189.jpg', [10, 106, 945, 1264]), ('crop_name_190.jpg', [10, 106, 945, 1264]), ('crop_name_192.jpg', [10, 106, 945, 1264]), ('crop_name_198.jpg', [10, 106, 945, 1264]), ('crop_name_199.jpg', [10, 106, 945, 1264]), ('crop_name_202.jpg', [10, 106, 945, 1264]), ('crop_name_204.jpg', [10, 106, 945, 1264]), ('crop_name_205.jpg', [10, 106, 945, 1264]), ('crop_name_207.jpg', [10, 106, 945, 1264]), ('crop_name_212.jpg', [10, 106, 945, 1264]), ('crop_name_218.jpg', [10, 106, 945, 1264]), ('crop ...
# image_name_188.jpg
# []
# image_name_189.jpg
# []
# image_name_190.jpg
# [('crop_name_28.jpg', [93, 158, 316, 536]), ('crop_name_238.jpg', [262, 369, 278, 403])]
# image_name_191.jpg
# [('crop_name_238.jpg', [289, 232, 305, 266])]
# image_name_192.jpg
# [('crop_name_238.jpg', [199, 188, 215, 222])]

# %%
import json
with open('jsondocument.json', 'w') as outfile:
    json.dump(imagedict, outfile, indent=2, cls=MyEncoder)
